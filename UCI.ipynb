# %%
import pandas as pd

from bs4 import BeautifulSoup
import requests

from keybert import KeyBERT
from tqdm import tqdm

# %%
uci_url = 'https://catalogue.uci.edu/allcourses/compsci/'
req = requests.get(uci_url)
soup = BeautifulSoup(req.text)
divs = soup.find_all("div", class_="courseblock")

# %%
class_id = []
class_title = []
desc = []
upper = []

for div in divs:
    # Extract Course ID and Title
    title_element = div.find("p", class_="courseblocktitle")
    if title_element:
        full_title = title_element.get_text(strip=True)
        course_code, course_name = full_title.split('.', 1)
        course_number = int("".join(filter(str.isdigit, course_code)))
        if course_number < 200:
            class_id.append(course_code.strip())
            class_title.append(course_name.split('.')[0].strip())

            desc_element = div.find("div", class_="courseblockdesc")
            desc_text = []
            if desc_element:
                for p in desc_element.find_all("p"):
                    desc_text.append(p.get_text(strip=True))
            desc.append(" ".join(desc_text))
            if course_number >= 100:
                upper.append(True)
            else:
                upper.append(False)

df = pd.DataFrame({
    "Course ID": class_id,
    "Course Title": class_title,
    "Upper": upper,
    "Skills": desc
})

# %%
def clean_description(text):
    text = text.split("Prerequisite:")[0]
    text = text.split("Restriction:")[0]
    return text.strip()

# %%
df['Skills']= df['Skills'].apply(clean_description)

# %%
def keyword_wrapper(doc):
    kw_model = KeyBERT() #instantiate model
    
    stop_words = ["cs", "prerequisite", "grade", "requirement", 
                  "courses", "instructor", "faculty", "computer", "student", "concurrently", "majors", "students"] #dont consider these words

    return [i[0] for i in kw_model.extract_keywords(doc, stop_words=stop_words, top_n=10)] #top 10 keywords

df['Skills'] = df['Skills'].apply(keyword_wrapper) #apply functon
df
# Out:
#        Course ID                                       Course Title  Upper  \
# 0    COMPSCI 103  Advanced Programming and Problem Solving with C++   True
# 1    COMPSCI 111                           Digital Image Processing   True
# 2    COMPSCI 112                                  Computer Graphics   True
# 3    COMPSCI 113                          Computer Game Development   True
# 4    COMPSCI 114          Projects in Advanced 3D Computer Graphics   True
# 5    COMPSCI 115                                Computer Simulation   True
# 6    COMPSCI 116               Computational Photography and Vision   True
# 7    COMPSCI 117                         Project in Computer Vision   True
# 8    COMPSCI 118                    Introduction to Virtual Reality   True
# 9    COMPSCI 121                              Information Retrieval   True
# 10  COMPSCI 122A                    Introduction to Data Management   True
# 11  COMPSCI 122B          Project in Databases and Web Applications   True
# 12  COMPSCI 122C                      Principles of Data Management   True
# 13  COMPSCI 122D                         Beyond SQL Data Management   True
# 14   COMPSCI 125                     Next Generation Search Systems   True
# 15   COMPSCI 131                 Parallel and Distributed Computing   True
# 16   COMPSCI 132                                  Computer Networks   True
# 17   COMPSCI 133                         Advanced Computer Networks   True
# 18   COMPSCI 134                      Computer and Network Security   True
# 19   COMPSCI 137                  Internet Applications Engineering   True
# 20   COMPSCI 141                Concepts in Programming Languages I   True
# 21  COMPSCI 142A                         Compilers and Interpreters   True
# 22  COMPSCI 142B                    Language Processor Construction   True
# 23  COMPSCI 143A                    Principles of Operating Systems   True
# 24  COMPSCI 143B           Project in Operating System Organization   True
# 25   COMPSCI 145                                  Embedded Software   True
# 26   COMPSCI 146      Programming in Multitasking Operating Systems   True
# 27   COMPSCI 147      Internet of Things (IoT) Software and Systems   True
# 28   COMPSCI 151                               Digital Logic Design   True
# 29   COMPSCI 152                      Computer Systems Architecture   True
# 30   COMPSCI 153                            Logic Design Laboratory   True
# 31   COMPSCI 154                         Computer Design Laboratory   True
# 32   COMPSCI 161                  Design and Analysis of Algorithms   True
# 33   COMPSCI 162                      Formal Languages and Automata   True
# 34   COMPSCI 163                                  Graph  Algorithms   True
# 35   COMPSCI 164      Computational Geometry and Geometric Modeling   True
# 36   COMPSCI 165          Project in Algorithms and Data Structures   True
# 37   COMPSCI 166                Quantum Computation and Information   True
# 38   COMPSCI 167               Introduction to Applied Cryptography   True
# 39   COMPSCI 169                       Introduction to Optimization   True
# 40   COMPSCI 171            Introduction to Artificial Intelligence   True
# 41  COMPSCI 172B                  Neural Networks and Deep Learning   True
# 42  COMPSCI 172C  Artificial Intelligence Frontiers: Technical, ...   True
# 43   COMPSCI 175                 Project in Artificial Intelligence   True
# 44   COMPSCI 177    Applications of Probability in Computer Science   True
# 45   COMPSCI 178                   Machine Learning and Data-Mining   True
# 46   COMPSCI 179  Algorithms for Probabilistic and Deterministic...   True
# 47  COMPSCI 180A                        Project in Computer Science   True
# 48  COMPSCI 180B                        Project in Computer Science   True
# 49   COMPSCI 183              Introduction to Computational Biology   True
# 50  COMPSCI 184A    Artificial Intelligence in Biology and Medicine   True
# 51  COMPSCI 184C                      Computational Systems Biology   True
# 52   COMPSCI 189                          Project in Bioinformatics   True
# 53   COMPSCI 190  Special Topics in Information and Computer Sci...   True
# 54  COMPSCI H198                                    Honors Research   True
# 55   COMPSCI 199                                   Individual Study   True
#
#                                                Skills
# 0   [programming, advanced, language, software, sk...
# 1   [multimedia, digital, segmentation, graphics, ...
# 2   [3d, graphics, polygonal, illumination, textur...
# 3   [2d, interactive, 3d, graphics, game, developm...
# 4   [3d, illumination, graphics, modeling, surface...
# 5   [simulation, stochastic, basic, distributions,...
# 6   [photographs, photography, stitching, panorami...
# 7   [3d, photographs, models, vision, tracking, ro...
# 8   [vr, virtual, 3d, software, graphics, platform...
# 9   [indexing, retrieval, clustering, classifying,...
# 10  [dbms, database, databases, sql, relational, m...
# 11  [databases, jdbc, database, odbc, java, applic...
# 12  [storage, data, processing, principles, techni...
# 13  [databases, nosql, database, data, sql, relati...
# 14  [search, multimedia, video, event, technology,...
# 15  [distributed, parallel, synchronization, progr...
# 16  [networking, network, internet, protocols, rou...
# 17  [protocols, unix, network, programming, networ...
# 18  [security, authentication, attacks, secure, au...
# 19  [interoperability, web, applications, http, in...
# 20  [programming, languages, paradigms, implementa...
# 21  [programming, syntax, lexical, processors, lan...
# 22  [interpreters, compilers, laboratory, language...
# 23  [processes, process, operating, systems, memor...
# 24  [hardware, specification, subsystem, component...
# 25  [embedded, hardware, architecture, computing, ...
# 26  [unix, programming, programmability, operating...
# 27  [iot, protocols, cloud, sensors, ecosystem, re...
# 28  [boolean, algorithms, hardware, implementation...
# 29  [microprocessor, hardware, implementation, des...
# 30  [debugging, msi, circuits, lsi, digital, integ...
# 31  [microprogramming, microprograms, instruction,...
# 32  [algorithms, algorithm, computing, sorting, ef...
# 33  [automata, grammars, languages, parsing, compu...
# 34  [algorithms, graph, traversal, connectivity, n...
# 35  [triangulation, geometry, algorithms, geometri...
# 36  [algorithms, encryption, sorting, compression,...
# 37  [quantum, entanglement, computation, complexit...
# 38  [cryptography, cryptographic, ciphers, signatu...
# 39  [optimization, constraints, constrained, uncon...
# 40  [representations, heuristic, representing, sem...
# 41  [bioinformatics, neural, learning, chemoinform...
# 42  [ethical, technologies, intelligence, artifici...
# 43  [knowledge, capabilities, intelligence, repres...
# 44  [probabilistic, algorithms, probability, topic...
# 45  [datasets, recognition, data, filtering, appli...
# 46  [probabilistic, graphical, models, bayesian, n...
# 47  [project, disciplines, knowledge, science, pro...
# 48  [project, disciplines, knowledge, science, pro...
# 49  [biomolecules, biomolecular, biochemistry, mol...
# 50  [molecular, computational, biology, rna, molec...
# 51  [pathways, gene, computational, transduction, ...
# 52  [bioinformatics, biomedical, lectures, computi...
# 53  [studies, topics, information, areas, science,...
# 54  [repeatability, research, honors, science, rep...
# 55  [research, repeatability, science, investigati...

# %%
df.to_csv('UCI.csv', index=False)
