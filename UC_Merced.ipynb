# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import time
from tqdm import tqdm

from bs4 import BeautifulSoup
import requests
import re

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager


from keybert import KeyBERT

# %%
UCM_home_url = "https://catalog.ucmerced.edu/content.php?filter%5B27%5D=CSE&filter%5B29%5D=&filter%5Bkeyword%5D=&filter%5B32%5D=1&filter%5Bcpage%5D=1&cur_cat_oid=23&expand=&navoid=2517&search_database=Filter#acalog_template_course_filter"


response = requests.get(UCM_home_url)

if response.status_code == 200:

    soup = BeautifulSoup(response.text, "html.parser")

    links = [soup.find_all("td", class_="width")[i].find_all('a')[0] for i in range(len(soup.find_all("td", class_="width")))]


    coids = [links[i]['href'][-5:] for i in range(len(links))]

    full_links = [f'https://catalog.ucmerced.edu/preview_course_nopop.php?catoid=23&coid={course}' for course in coids]
    
else:
    print('Request failed:', response.status_code)

# %%
data = []
for url in full_links:
    resposne = requests.get(url)
    if response.status_code == 200:

        driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

        driver.get(url)

        time.sleep(1)

        rendered_html = driver.page_source
        
        driver.quit()

        soup = BeautifulSoup(rendered_html, "html.parser")


        soup = soup.find('td', class_ = 'block_content')

        header = soup.find("h1", id="course_preview_title")

        header_text = header.get_text(strip=True)
        course_code, course_title = [part.strip() for part in header_text.split(":", 1)]

        course_description = ""
        for br in soup.find_all("br"):
            next_text = br.next_sibling
            if next_text and isinstance(next_text, str):
                cleaned = next_text.strip()
                if cleaned and "Unit" not in cleaned:
                    course_description = cleaned
                    break

        result = [course_code, course_title, course_description]
        data.append(result)

    
    else:
        print('Request failed:', response.status_code)

df = pd.DataFrame(columns = ['Course ID', 'Course Title', 'Description'], data=data)
df.head()
# Out:
#   Course ID                           Course Title  \
# 0   CSE 005  Introduction to Computer Applications
# 1   CSE 015                   Discrete Mathematics
# 2   CSE 019              Introduction to Computing
# 3   CSE 022            Introduction to Programming
# 4   CSE 024                   Advanced Programming
#
#                                          Description
# 0  Presents the use of computers to control infor...
# 1  Explores basic concepts of discrete mathematic...
# 2  Presents the basics of programming to a studen...
# 3  Introduces students to programming, computatio...
# 4  Intended for students with basic to intermedia...

# %%
df['Upper Div'] = df['Course ID'].str.extract(r'(\d+)')[0].astype(int).apply(lambda x: x >= 100) #Upper div class is 100-199 class
df.head()
# Out:
#    Course ID                                   Course Title  \
# 0    CSE 005          Introduction to Computer Applications
# 1    CSE 015                           Discrete Mathematics
# 2    CSE 019                      Introduction to Computing
# 3    CSE 022                    Introduction to Programming
# 4    CSE 024                           Advanced Programming
# 5    CSE 030                                Data Structures
# 6    CSE 031    Computer Organization and Assembly Language
# 7    CSE 095          Lower Division Undergraduate Research
# 8    CSE 098            Lower Division Directed Group Study
# 9    CSE 099                Lower Division Individual Study
# 10   CSE 100                  Algorithm Design and Analysis
# 11   CSE 106                          Exploratory Computing
# 12   CSE 107       Introduction to Digital Image Processing
# 13   CSE 108                     Full Stack Web Development
# 14   CSE 111                               Database Systems
# 15   CSE 120                           Software Engineering
# 16   CSE 126         Information Systems and Service Design
# 17   CSE 130                   Introduction to Cryptography
# 18   CSE 135          Introduction to Theory of Computation
# 19   CSE 140                          Computer Architecture
# 20   CSE 141          Introduction to Compiler Construction
# 21   CSE 150                              Operating Systems
# 22   CSE 151                     Advanced Operating Systems
# 23   CSE 155     Introduction to Human-Computer Interaction
# 24   CSE 157       Signal Processing for Internet of Things
# 25   CSE 160                              Computer Networks
# 26   CSE 162                               Mobile Computing
# 27   CSE 165  Introduction to Object Orientated Programming
# 28   CSE 168                   Distributed Software Systems
# 29   CSE 170                              Computer Graphics
# 30   CSE 171                               Game Programming
# 31   CSE 173           Computational Cognitive Neuroscience
# 32   CSE 175        Introduction to Artificial Intelligence
# 33   CSE 176               Introduction to Machine Learning
# 34   CSE 177                Database Systems Implementation
# 35   CSE 178                Computers and Networks Security
# 36   CSE 179             Introduction to Parallel Computing
# 37   CSE 180                       Introduction to Robotics
# 38   CSE 185                Introduction to Computer Vision
# 39   CSE 190     Topics in Computer Science and Engineering
# 40   CSE 195          Upper Division Undergraduate Research
# 41   CSE 198            Upper Division Directed Group Study
# 42   CSE 199                Upper Division Individual Study
#
#                                           Description  Upper Div
# 0   Presents the use of computers to control infor...      False
# 1   Explores basic concepts of discrete mathematic...      False
# 2   Presents the basics of programming to a studen...      False
# 3   Introduces students to programming, computatio...      False
# 4   Intended for students with basic to intermedia...      False
# 5   Focuses on the design, analysis, and implement...      False
# 6   Exposes students to the underlying structure o...      False
# 7                                Supervised research.      False
# 8                      Repeats Allowed for Credit: 99      False
# 9                      Repeats Allowed for Credit: 99      False
# 10  Introduction to the design and analysis of com...       True
# 11  Our ability to manipulate data depends on and ...       True
# 12  Overview of digital image processing including...       True
# 13  Explores topics related to both front end and ...       True
# 14  Principles of database design and operation. R...       True
# 15  Teams work on approved design projects or on s...       True
# 16  Presents an end-to-end view of the design life...       True
# 17  Introduces the basic theory and practice of cr...       True
# 18  Understanding the inherent capabilities and li...       True
# 19  Fundamental concepts of digital computer desig...       True
# 20  Explores basic concepts and techniques in comp...       True
# 21  Concepts of computer operating systems includi...       True
# 22  Introduces the concept of advanced Operating S...       True
# 23  Introduces students to the basic concepts in t...       True
# 24  Introduces methods for signal processing betwe...       True
# 25  Design concepts and implementation features of...       True
# 26  Introduces mobile cloud computing’s basic conc...       True
# 27  Topics include object-oriented programming con...       True
# 28  Covers the foundations of distributed software...       True
# 29  Basic algorithms in computer graphics enabling...       True
# 30  Covers the main algorithms and techniques used...       True
# 31  Design and analysis of computational simulatio...       True
# 32  Overview of the main concepts and methods unde...       True
# 33  Survey of techniques for development and analy...       True
# 34  Studies the internals of a database management...       True
# 35  Introduces fundamental concepts in the design ...       True
# 36  Parallel computing is pervasive. From embedded...       True
# 37  Covers the basic of robotics focusing on the a...       True
# 38  Overview of fundamental image processing and p...       True
# 39  Covers special topics within Computer Science ...       True
# 40                               Supervised research.       True
# 41                     Repeats Allowed for Credit: 99       True
# 42                     Repeats Allowed for Credit: 99       True

# %%
start = time.time() #time it
tqdm.pandas() #time it

def keyword_wrapper(doc):
    kw_model = KeyBERT() #instantiate model
    
    stop_words = ["cs", "prerequisite", "grade", "requirement", 
    "courses", "instructor", "faculty", "computer", "student", "concurrently", "majors",
    "approach", "aspects", "awarded",
    "concepts", "course", "courses", "credit", "design", "fields",
    "foundation", "fundamental", "fundamentals", "introduction", "issues", "level",
    "lower", "major", "methods", "none", "overview", "perspectives",
    "practice", "practices", "principles", "process", "processes",
    "programs", "related", "required", "requirement", "role",
    "skills", "study", "techniques", "tools", "topics", "understanding",
    "upper", "various", "work"] #dont consider these words

    return [i[0] for i in kw_model.extract_keywords(doc, stop_words=stop_words, top_n=10)] #top 10 keywords

df['keywords'] = df['Description'].progress_apply(keyword_wrapper) #apply functon
df.head()
end = time.time()
print('Time:', end - start) #print time
# Out:
# 100%|██████████| 43/43 [00:56<00:00,  1.32s/it]
# Time: 56.921117067337036

# %%
df= df[['Course ID',	'Course Title',	'Upper Div',	'keywords']]
df.columns = ['Course ID', 'Course Title', 'Upper', 'Skills']
df.head()
# Out:
#   Course ID                           Course Title  Upper  \
# 0   CSE 005  Introduction to Computer Applications  False
# 1   CSE 015                   Discrete Mathematics  False
# 2   CSE 019              Introduction to Computing  False
# 3   CSE 022            Introduction to Programming  False
# 4   CSE 024                   Advanced Programming  False
#
#                                               Skills
# 0  [programming, computers, data, security, infor...
# 1  [mathematics, discrete, disciplines, basic, gr...
# 2  [programming, basics, arrays, variables, stude...
# 3  [programming, python, students, teaching, comp...
# 4  [programming, pointers, basic, students, langu...

# %%
df.to_csv('UC_Merced.csv', index=False)
